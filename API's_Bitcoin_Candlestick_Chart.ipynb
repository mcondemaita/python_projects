# %% [markdown]
# <a href="https://colab.research.google.com/github/mcondemaita/python_projects/blob/main/API's_Bitcoin_Candlestick_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# APIs  Appprication program Interface
# Rest APIs:
#   REpresetation State Transfer APIs use to interact with web services
#     Rules:
#     1. Communication
#     2. Input or Request
#     3. Output or Response
#
#     Usually response using HTTP format Json

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import plotly.graph_objects as go

# !pip install plotly

from datetime import datetime, timezone

# %%
# !pip install pycoingecko
from pycoingecko import CoinGeckoAPI
cg= CoinGeckoAPI()
bitcoin_data = cg.get_coin_market_chart_by_id(id="bitcoin", vs_currency='usd', days=30) #funtion to request data

# %%
bitcoin_price_data = bitcoin_data['prices'] #only select what we need

# %%
data = pd.DataFrame(bitcoin_price_data, columns=['TimeStamp', 'Price'])
data
# Out:
#          TimeStamp         Price
# 0    1642518077038  41356.611128
# 1    1642521723376  41702.562592
# 2    1642525337159  41796.530470
# 3    1642528983594  41550.284114
# 4    1642532466377  41716.195092
# ..             ...           ...
# 712  1645095638090  43105.397729
# 713  1645099289381  43222.072667
# 714  1645102885073  43288.555489
# 715  1645106528668  42319.138403
# 716  1645109368000  42147.221405
#
# [717 rows x 2 columns]

# %%
#fix TimeStamp 
data['Date'] = pd.to_datetime(data['TimeStamp'], unit = 'ms') #output to miloseconds 
data['Date']
# Out:
# 0     2022-01-18 15:01:17.038
# 1     2022-01-18 16:02:03.376
# 2     2022-01-18 17:02:17.159
# 3     2022-01-18 18:03:03.594
# 4     2022-01-18 19:01:06.377
#                 ...
# 712   2022-02-17 11:00:38.090
# 713   2022-02-17 12:01:29.381
# 714   2022-02-17 13:01:25.073
# 715   2022-02-17 14:02:08.668
# 716   2022-02-17 14:49:28.000
# Name: Date, Length: 717, dtype: datetime64[ns]

# %%
data #we append the date to our data
# Out:
#          TimeStamp         Price                    Date
# 0    1642518077038  41356.611128 2022-01-18 15:01:17.038
# 1    1642521723376  41702.562592 2022-01-18 16:02:03.376
# 2    1642525337159  41796.530470 2022-01-18 17:02:17.159
# 3    1642528983594  41550.284114 2022-01-18 18:03:03.594
# 4    1642532466377  41716.195092 2022-01-18 19:01:06.377
# ..             ...           ...                     ...
# 712  1645095638090  43105.397729 2022-02-17 11:00:38.090
# 713  1645099289381  43222.072667 2022-02-17 12:01:29.381
# 714  1645102885073  43288.555489 2022-02-17 13:01:25.073
# 715  1645106528668  42319.138403 2022-02-17 14:02:08.668
# 716  1645109368000  42147.221405 2022-02-17 14:49:28.000
#
# [717 rows x 3 columns]

# %%
#represent on a candlestick data 
candlestick_data = data.groupby(data.Date.dt.date).agg({'Price': ['min', 'max', 'first', 'last']}) #into a dictionary 
candlestick_data.head()
# Out:
#                    Price
#                      min           max         first          last
# Date
# 2022-01-18  41356.611128  42498.478539  41356.611128  42498.478539
# 2022-01-19  41265.005495  42652.558156  42395.458792  42035.879540
# 2022-01-20  41244.725588  43308.039567  41749.551431  41244.725588
# 2022-01-21  35761.710944  41011.486226  40707.682414  35761.710944
# 2022-01-22  34527.652838  36639.176855  36385.341363  34935.310598

# %%
#plug them in a figure 
fig = go.Figure(data =[go.Candlestick(x= candlestick_data.index, 
                open= candlestick_data['Price']['first'],
                high = candlestick_data['Price']['max'],
                low = candlestick_data['Price']['min'],
                close = candlestick_data['Price']['last'])
                ])
fig.update_layout(xaxis_rangeslider_visible=False, xaxis_title ='Date', 
                  yaxis_title='Price USD $', title = 'Bitcoin Cadlestick chart Over the 30 Days')

#plot(fig, filename= 'bitcoin_candlestick_graph.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
